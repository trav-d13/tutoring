# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Newton Raphson
# Excellent visualization in order to understand the Newton Raphson method.
# The below visualization draws inspiration from the above video.
#
# The Newton-Raphson method is a numerical root finding method.
# The inityial value x_0 determines the time taken to find the root, and which root is found in the case of multiple roots.
#
# ![image.png](attachment:image.png)
#
# The below is the pseudocode of the Newton-Raphson method:
# ```
# newton_raphson(x_init, epsilon, function):
#
#     # The difference value initializes the current_x to be different from the old_x at the start.
#     # Note the difference value could effect which root will be found
#     old_x = x_init
#     current_x = old_x + difference
#
#     # Loop to iteratively solve
#     while |old_x - current_x| > epsilon:
#         # Update the current_x using the above equation
#         current_x = current_x - (function(x_current) / derivative(x))
#
#     return current_x
# ```
#
# Note, the Newton Raphson method can be applied to multi-variate root finding. In this case the derivative will be in the form of a Jacobian and involve linear programming methods to deal with matrix multiplication, etc.

# %% [markdown]
# ## Gaussian Elimination
#
# Source for below example from: https://youtu.be/eDb6iugi6Uk
# ![image.png](attachment:image.png)
