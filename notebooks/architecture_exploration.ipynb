# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ## Architecture Initial Exploration
#
# Initial exploration into the capacity of image processing and Neural Networks to simplify and automate the repetitive elements of Architecture.
# Reference for the below edge detection example using Sobel edge detection methods: https://learnopencv.com/edge-detection-using-opencv/.
# The purpose of this notebook is to apply existing edge detection algorithms to determine the ability of these algorithms to capture architectural detail. All attributions of the code go to the original source.

# %% [markdown]
# ### Sobel Edge Detection

# %%
img = cv2.imread('architecture_cache/architecture_ex_02.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# Convert the image to greyscale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')
plt.show()

# %% [markdown]
# Blur the image using Gaussian Blur.
# This will remove smaller redundant detail not neccessarily critical to the major edge detection.

# %%
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
plt.imshow(img_blur, cmap='gray')
plt.show()

# %% [markdown]
# Perform Sobel edge detection.

# %%
sobel_x = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobel_y = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobel_xy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection

# %%
plt.imshow(sobel_x, cmap='gray')
plt.show()

# %%
plt.imshow(sobel_y, cmap='gray')
plt.show()

# %%
plt.imshow(sobel_xy, cmap='gray')
plt.show()

# %% [markdown]
# ### Canny Edge Detection Alternative

# %%
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
plt.imshow(edges, cmap='gray')
plt.show()
